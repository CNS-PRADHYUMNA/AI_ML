# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
from sklearn.linear_model import  LinearRegression
from sklearn.model_selection import train_test_split as tts

# %%
ds=pd.read_csv("Salary_Data.csv")
# X=[ds['YearsExperience'].values]
# y=[ds['Salary']]
X=ds.iloc[:,:-1].values
y=ds.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.2, random_state = 0)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X=X_test)
# Out:
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,lr.predict(X_train),color='blue')
plt.title("sal vs exp (training set)")
plt.xlabel('exp')
plt.ylabel('sal')
plt.show()

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,lr.predict(X_train),color='blue')
plt.title("sal vs exp (testset)")
plt.xlabel('exp')
plt.ylabel('sal')
plt.show()

# %%
print(lr.predict([[0]]).round())
# Out:
# [26780.]

# %%
print(lr.coef_)
print(lr.intercept_)
print("y=mx+c")
print("y=sal")
print("m=9312.57512673")
print("x=exp")
print("c=26780.09915062818")
print("Salary=9345.94×YearsExperience+26816.19")
# Out:
# [9312.57512673]
# 26780.09915062818
# y=mx+c
# y=sal
# m=9312.57512673
# x=exp
# c=26780.09915062818
# Salary=9345.94×YearsExperience+26816.19
